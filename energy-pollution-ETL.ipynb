# %%
import pandas as pd
import numpy as np

# %%
energy_data = pd.read_excel ("Data Files/emissions_region2018.xlsx",header=1)

# %%
energy_data.head()
# Out:
#    Year Census Division and State  \
# 0  2018               New England
# 1  2018               Connecticut
# 2  2018                     Maine
# 3  2018             Massachusetts
# 4  2018             New Hampshire
#
#    \nCarbon Dioxide (CO2)\n(Thousand Metric Tons)  \
# 0                                       27317.399
# 1                                        9591.483
# 2                                        2201.608
# 3                                        9975.913
# 4                                        2190.562
#
#    \nSulfur Dioxide (SO2)\n(Thousand Metric Tons)  \
# 0                                          12.171
# 1                                           0.886
# 2                                           7.306
# 3                                           2.519
# 4                                           1.350
#
#    \nNitrogen Oxides (NOx)\n(Thousand Metric Tons)  \
# 0                                           25.345
# 1                                            6.048
# 2                                            5.966
# 3                                            8.456
# 4                                            2.502
#
#    Generation (Thousand Megawatthours)  \
# 0                           105548.461
# 1                            39453.552
# 2                            11280.700
# 3                            27172.882
# 4                            17087.156
#
#    Kilograms of CO2 per Megawatthour of Generation  \
# 0                                          258.814
# 1                                          243.108
# 2                                          195.166
# 3                                          367.128
# 4                                          128.199
#
#    Grams of\nSO2 per Megawatthour of Generation  \
# 0                                       115.316
# 1                                        22.449
# 2                                       647.635
# 3                                        92.703
# 4                                        79.004
#
#    Grams of\nNOx per Megawatthour of Generation
# 0                                       240.128
# 1                                       153.301
# 2                                       528.872
# 3                                       311.195
# 4                                       146.428

# %%
state_dict = {'Connecticut' : 'New England',
'Maine' : 'New England',
'Massachusetts' : 'New England',
'New Hampshire' : 'New England',
'Rhode Island' : 'New England',
'Vermont' : 'New England',
'New Jersey' : 'Middle Atlantic',
'New York' : 'Middle Atlantic',
'Pennsylvania' : 'Middle Atlantic',
'Illinois' : 'East North Central',
'Indiana' : 'East North Central',
'Michigan' : 'East North Central',
'Ohio' : 'East North Central',
'Wisconsin' : 'East North Central',
'Iowa' : 'West North Central',
'Kansas' : 'West North Central',
'Minnesota' : 'West North Central',
'Missouri' : 'West North Central',
'Nebraska' : 'West North Central',
'North Dakota' : 'West North Central',
'South Dakota' : 'West North Central',
'Delaware' : 'South Atlantic',
'District of Columbia' : 'South Atlantic',
'Florida' : 'South Atlantic',
'Georgia' : 'South Atlantic',
'Maryland' : 'South Atlantic',
'North Carolina' : 'South Atlantic',
'South Carolina' : 'South Atlantic',
'Virginia' : 'South Atlantic',
'West Virginia' : 'South Atlantic',
'Alabama' : 'East South Central',
'Kentucky' : 'East South Central',
'Mississippi' : 'East South Central',
'Tennessee' : 'East South Central',
'Arkansas' : 'West South Central',
'Louisiana' : 'West South Central',
'Oklahoma' : 'West South Central',
'Texas' : 'West South Central',
'Arizona' : 'Mountain',
'Colorado' : 'Mountain',
'Idaho' : 'Mountain',
'Montana' : 'Mountain',
'Nevada' : 'Mountain',
'New Mexico' : 'Mountain',
'Utah' : 'Mountain',
'Wyoming' : 'Mountain',
'California' : 'Pacific Contiguous',
'Oregon' : 'Pacific Contiguous',
'Washington' : 'Pacific Contiguous',
'Alaska' : 'Pacific Noncontiguous',
'Hawaii' : 'Pacific Noncontiguous'}

# %%
energy_data["Region"] = None

# %%
for state, region in state_dict.items():
    energy_data['Region'] = np.where(energy_data['Census Division and State'] == state, region, energy_data['Region'])

# %%
energy_data.head(20)
# Out:
#     Year Census Division and State  \
# 0   2018               New England
# 1   2018               Connecticut
# 2   2018                     Maine
# 3   2018             Massachusetts
# 4   2018             New Hampshire
# 5   2018              Rhode Island
# 6   2018                   Vermont
# 7   2018           Middle Atlantic
# 8   2018                New Jersey
# 9   2018                  New York
# 10  2018              Pennsylvania
# 11  2018        East North Central
# 12  2018                  Illinois
# 13  2018                   Indiana
# 14  2018                  Michigan
# 15  2018                      Ohio
# 16  2018                 Wisconsin
# 17  2018        West North Central
# 18  2018                      Iowa
# 19  2018                    Kansas
#
#     \nCarbon Dioxide (CO2)\n(Thousand Metric Tons)  \
# 0                                        27317.399
# 1                                         9591.483
# 2                                         2201.608
# 3                                         9975.913
# 4                                         2190.562
# 5                                         3347.857
# 6                                            9.975
# 7                                       123878.859
# 8                                        18911.751
# 9                                        27936.384
# 10                                       77030.724
# 11                                      345079.936
# 12                                       72260.775
# 13                                       91553.529
# 14                                       61435.293
# 15                                       78051.141
# 16                                       41779.199
# 17                                      213155.950
# 18                                       34252.878
# 19                                       23747.647
#
#     \nSulfur Dioxide (SO2)\n(Thousand Metric Tons)  \
# 0                                           12.171
# 1                                            0.886
# 2                                            7.306
# 3                                            2.519
# 4                                            1.350
# 5                                            0.063
# 6                                            0.048
# 7                                           80.966
# 8                                            3.077
# 9                                           10.764
# 10                                          67.126
# 11                                         346.013
# 12                                          80.056
# 13                                          62.812
# 14                                          74.327
# 15                                         105.522
# 16                                          23.296
# 17                                         249.148
# 18                                          33.782
# 19                                           4.949
#
#     \nNitrogen Oxides (NOx)\n(Thousand Metric Tons)  \
# 0                                            25.345
# 1                                             6.048
# 2                                             5.966
# 3                                             8.456
# 4                                             2.502
# 5                                             1.885
# 6                                             0.488
# 7                                            86.277
# 8                                            10.077
# 9                                            28.933
# 10                                           47.266
# 11                                          250.773
# 12                                           36.922
# 13                                           74.905
# 14                                           52.077
# 15                                           60.602
# 16                                           26.268
# 17                                          176.195
# 18                                           28.795
# 19                                           17.392
#
#     Generation (Thousand Megawatthours)  \
# 0                            105548.461
# 1                             39453.552
# 2                             11280.700
# 3                             27172.882
# 4                             17087.156
# 5                              8375.257
# 6                              2178.915
# 7                            422939.928
# 8                             75033.600
# 9                            132520.498
# 10                           215385.830
# 11                           609421.539
# 12                           188003.357
# 13                           113459.711
# 14                           115837.095
# 15                           126184.610
# 16                            65936.767
# 17                           350241.930
# 18                            63380.566
# 19                            51710.214
#
#     Kilograms of CO2 per Megawatthour of Generation  \
# 0                                           258.814
# 1                                           243.108
# 2                                           195.166
# 3                                           367.128
# 4                                           128.199
# 5                                           399.732
# 6                                             4.578
# 7                                           292.899
# 8                                           252.044
# 9                                           210.808
# 10                                          357.641
# 11                                          566.242
# 12                                          384.359
# 13                                          806.925
# 14                                          530.359
# 15                                          618.547
# 16                                          633.625
# 17                                          608.596
# 18                                          540.432
# 19                                          459.245
#
#     Grams of\nSO2 per Megawatthour of Generation  \
# 0                                        115.316
# 1                                         22.449
# 2                                        647.635
# 3                                         92.703
# 4                                         79.004
# 5                                          7.570
# 6                                         21.858
# 7                                        191.437
# 8                                         41.010
# 9                                         81.223
# 10                                       311.653
# 11                                       567.772
# 12                                       425.821
# 13                                       553.605
# 14                                       641.655
# 15                                       836.249
# 16                                       353.307
# 17                                       711.359
# 18                                       533.008
# 19                                        95.713
#
#     Grams of\nNOx per Megawatthour of Generation              Region
# 0                                        240.128                None
# 1                                        153.301         New England
# 2                                        528.872         New England
# 3                                        311.195         New England
# 4                                        146.428         New England
# 5                                        225.058         New England
# 6                                        223.882         New England
# 7                                        203.993                None
# 8                                        134.303     Middle Atlantic
# 9                                        218.332     Middle Atlantic
# 10                                       219.449     Middle Atlantic
# 11                                       411.494                None
# 12                                       196.391  East North Central
# 13                                       660.187  East North Central
# 14                                       449.571  East North Central
# 15                                       480.262  East North Central
# 16                                       398.381  East North Central
# 17                                       503.067                None
# 18                                       454.316  West North Central
# 19                                       336.338  West North Central

# %%
energy_dataclean = energy_data.dropna()
energy_dataclean.head()
# Out:
#    Year Census Division and State  \
# 1  2018               Connecticut
# 2  2018                     Maine
# 3  2018             Massachusetts
# 4  2018             New Hampshire
# 5  2018              Rhode Island
#
#    \nCarbon Dioxide (CO2)\n(Thousand Metric Tons)  \
# 1                                        9591.483
# 2                                        2201.608
# 3                                        9975.913
# 4                                        2190.562
# 5                                        3347.857
#
#    \nSulfur Dioxide (SO2)\n(Thousand Metric Tons)  \
# 1                                           0.886
# 2                                           7.306
# 3                                           2.519
# 4                                           1.350
# 5                                           0.063
#
#    \nNitrogen Oxides (NOx)\n(Thousand Metric Tons)  \
# 1                                            6.048
# 2                                            5.966
# 3                                            8.456
# 4                                            2.502
# 5                                            1.885
#
#    Generation (Thousand Megawatthours)  \
# 1                            39453.552
# 2                            11280.700
# 3                            27172.882
# 4                            17087.156
# 5                             8375.257
#
#    Kilograms of CO2 per Megawatthour of Generation  \
# 1                                          243.108
# 2                                          195.166
# 3                                          367.128
# 4                                          128.199
# 5                                          399.732
#
#    Grams of\nSO2 per Megawatthour of Generation  \
# 1                                        22.449
# 2                                       647.635
# 3                                        92.703
# 4                                        79.004
# 5                                         7.570
#
#    Grams of\nNOx per Megawatthour of Generation       Region
# 1                                       153.301  New England
# 2                                       528.872  New England
# 3                                       311.195  New England
# 4                                       146.428  New England
# 5                                       225.058  New England

# %%
energydata_final = energy_dataclean.rename(columns={"Census Division and State":"State",
                                 "\nCarbon Dioxide (CO2)\n(Thousand Metric Tons)":"CO2_ThousandMetricTons",
                         "\nSulfur Dioxide (SO2)\n(Thousand Metric Tons)":"SO2_ThousandMetricTons",
                        "\nNitrogen Oxides (NOx)\n(Thousand Metric Tons)":"NOx_ThousandMetricTons",
                        "Generation (Thousand Megawatthours)":"Generation_Megawatthours",
                        "Kilograms of CO2 per Megawatthour of Generation":"CO2_Kilograms_per_Megawatthour",
                        "Grams of\nSO2 per Megawatthour of Generation":"SO2_Grams_per_Megawatthour",
                        "Grams of\nNOx per Megawatthour of Generation":"NOx_Grams_Per_megawatthour"})

# %%
energydata_final.head()
# Out:
#    Year          State  CO2_ThousandMetricTons  SO2_ThousandMetricTons  \
# 1  2018    Connecticut                9591.483                   0.886
# 2  2018          Maine                2201.608                   7.306
# 3  2018  Massachusetts                9975.913                   2.519
# 4  2018  New Hampshire                2190.562                   1.350
# 5  2018   Rhode Island                3347.857                   0.063
#
#    NOx_ThousandMetricTons  Generation_Megawatthours  \
# 1                   6.048                 39453.552
# 2                   5.966                 11280.700
# 3                   8.456                 27172.882
# 4                   2.502                 17087.156
# 5                   1.885                  8375.257
#
#    CO2_Kilograms_per_Megawatthour  SO2_Grams_per_Megawatthour  \
# 1                         243.108                      22.449
# 2                         195.166                     647.635
# 3                         367.128                      92.703
# 4                         128.199                      79.004
# 5                         399.732                       7.570
#
#    NOx_Grams_Per_megawatthour       Region
# 1                     153.301  New England
# 2                     528.872  New England
# 3                     311.195  New England
# 4                     146.428  New England
# 5                     225.058  New England

# %%
pollution_data = pd.read_csv('Data Files/Net_generation_for_all_sectors (3).csv', header = 4)
pollution_data = pollution_data.drop(columns = ['units', 'source key'])
pollution_data = pollution_data.set_index('description')

pollution_data.head()
# Out:
#                                           Jan 2001 Feb 2001 Mar 2001 Apr 2001  \
# description
# Net generation for all sectors                 NaN      NaN      NaN      NaN
# United States                                  NaN      NaN      NaN      NaN
# United States : all fuels (utility-scale)   332493   282940   300707   278079
# United States : coal                        177287   149735   155269   140671
# United States : petroleum liquids            17300     9626    10981    10237
#
#                                           May 2001 Jun 2001 Jul 2001 Aug 2001  \
# description
# Net generation for all sectors                 NaN      NaN      NaN      NaN
# United States                                  NaN      NaN      NaN      NaN
# United States : all fuels (utility-scale)   300492   327694   357614   370533
# United States : coal                        151593   162616   179060   183116
# United States : petroleum liquids             9641    10997    10050    13235
#
#                                           Sep 2001 Oct 2001  ...  Sep 2019  \
# description                                                  ...
# Net generation for all sectors                 NaN      NaN  ...       NaN
# United States                                  NaN      NaN  ...       NaN
# United States : all fuels (utility-scale)   306929   294734  ...  359545.0
# United States : coal                        154158   148931  ...   85918.0
# United States : petroleum liquids             6432     5573  ...     942.0
#
#                                            Oct 2019  Nov 2019  Dec 2019  \
# description
# Net generation for all sectors                  NaN       NaN       NaN
# United States                                   NaN       NaN       NaN
# United States : all fuels (utility-scale)  321875.0  316672.0  337253.0
# United States : coal                        66829.0   75560.0   72554.0
# United States : petroleum liquids             955.0     911.0     961.0
#
#                                            Jan 2020  Feb 2020  Mar 2020  \
# description
# Net generation for all sectors                  NaN       NaN       NaN
# United States                                   NaN       NaN       NaN
# United States : all fuels (utility-scale)  339320.0  316934.0  305779.0
# United States : coal                        65170.0   56072.0   50586.0
# United States : petroleum liquids             934.0     749.0     704.0
#
#                                            Apr 2020  May 2020  Jun 2020
# description
# Net generation for all sectors                  NaN       NaN       NaN
# United States                                   NaN       NaN       NaN
# United States : all fuels (utility-scale)  274876.0  303434.0  352936.0
# United States : coal                        40576.0   46488.0   65475.0
# United States : petroleum liquids             624.0     694.0     849.0
#
# [5 rows x 234 columns]

# %%
new_pollution_data = pollution_data.transpose()

# %%
new_pollution_data = new_pollution_data.drop(columns = ["Net generation for all sectors", 'United States', 'United States : other renewables'])

# %%
new_pollution_data.tail(10)
# Out:
# description United States : all fuels (utility-scale) United States : coal  \
# Sep 2019                                       359545                85918
# Oct 2019                                       321875                66829
# Nov 2019                                       316672                75560
# Dec 2019                                       337253                72554
# Jan 2020                                       339320                65170
# Feb 2020                                       316934                56072
# Mar 2020                                       305779                50586
# Apr 2020                                       274876                40576
# May 2020                                       303434                46488
# Jun 2020                                       352936                65475
#
# description United States : petroleum liquids United States : petroleum coke  \
# Sep 2019                                  942                            638
# Oct 2019                                  955                            198
# Nov 2019                                  911                            339
# Dec 2019                                  961                            409
# Jan 2020                                  934                            687
# Feb 2020                                  749                            452
# Mar 2020                                  704                            708
# Apr 2020                                  624                            626
# May 2020                                  694                            632
# Jun 2020                                  849                            827
#
# description United States : natural gas United States : other gases  \
# Sep 2019                         150753                        1139
# Oct 2019                         133667                         997
# Nov 2019                         117762                        1196
# Dec 2019                         129342                        1136
# Jan 2020                         132980                        1211
# Feb 2020                         126024                        1234
# Mar 2020                         123569                        1109
# Apr 2020                         108138                         801
# May 2020                         116236                         862
# Jun 2020                         143247                         832
#
# description United States : nuclear  \
# Sep 2019                      66064
# Oct 2019                      62033
# Nov 2019                      64125
# Dec 2019                      73074
# Jan 2020                      74204
# Feb 2020                      65950
# Mar 2020                      63997
# Apr 2020                      59170
# May 2020                      64338
# Jun 2020                      67205
#
# description United States : conventional hydroelectric United States : wind  \
# Sep 2019                                         16324                24385
# Oct 2019                                         16292                28136
# Nov 2019                                         20520                25603
# Dec 2019                                         22206                27183
# Jan 2020                                         24286                28403
# Feb 2020                                         25077                29235
# Mar 2020                                         22269                29483
# Apr 2020                                         20771                29534
# May 2020                                         29468                28180
# Jun 2020                                         28621                30147
#
# description United States : all utility-scale solar  \
# Sep 2019                                       6752
# Oct 2019                                       6131
# Nov 2019                                       4377
# Dec 2019                                       3494
# Jan 2020                                       4555
# Feb 2020                                       5652
# Mar 2020                                       6314
# Apr 2020                                       8010
# May 2020                                       9742
# Jun 2020                                       9467
#
# description United States : geothermal United States : biomass  \
# Sep 2019                          1384                    4788
# Oct 2019                          1277                    4647
# Nov 2019                          1112                    4604
# Dec 2019                          1301                    4996
# Jan 2020                          1255                    4957
# Feb 2020                          1156                    4615
# Mar 2020                          1490                    4843
# Apr 2020                          1356                    4524
# May 2020                          1421                    4654
# Jun 2020                          1342                    4403
#
# description United States : wood and wood-derived fuels  \
# Sep 2019                                           3282
# Oct 2019                                           3081
# Nov 2019                                           3107
# Dec 2019                                           3407
# Jan 2020                                           3349
# Feb 2020                                           3154
# Mar 2020                                           3223
# Apr 2020                                           2992
# May 2020                                           3103
# Jun 2020                                           2994
#
# description United States : other biomass  \
# Sep 2019                             1506
# Oct 2019                             1565
# Nov 2019                             1497
# Dec 2019                             1588
# Jan 2020                             1609
# Feb 2020                             1461
# Mar 2020                             1620
# Apr 2020                             1532
# May 2020                             1550
# Jun 2020                             1409
#
# description United States : hydro-electric pumped storage  \
# Sep 2019                                             -671
# Oct 2019                                             -373
# Nov 2019                                             -509
# Dec 2019                                             -529
# Jan 2020                                             -406
# Feb 2020                                             -247
# Mar 2020                                             -353
# Apr 2020                                             -325
# May 2020                                             -367
# Jun 2020                                             -499
#
# description United States : other United States : all solar  \
# Sep 2019                     1128                      9968
# Oct 2019                     1087                      8971
# Nov 2019                     1070                      6608
# Dec 2019                     1126                      5541
# Jan 2020                     1084                      6848
# Feb 2020                      966                      8261
# Mar 2020                     1058                      9723
# Apr 2020                     1072                     11811
# May 2020                     1088                     13987
# Jun 2020                     1020                     13725
#
# description United States : small-scale solar photovoltaic  \
# Sep 2019                                              3216
# Oct 2019                                              2840
# Nov 2019                                              2232
# Dec 2019                                              2046
# Jan 2020                                              2293
# Feb 2020                                              2609
# Mar 2020                                              3409
# Apr 2020                                              3801
# May 2020                                              4245
# Jun 2020                                              4258
#
# description United States : all utility-scale solar
# Sep 2019                                       6752
# Oct 2019                                       6131
# Nov 2019                                       4377
# Dec 2019                                       3494
# Jan 2020                                       4555
# Feb 2020                                       5652
# Mar 2020                                       6314
# Apr 2020                                       8010
# May 2020                                       9742
# Jun 2020                                       9467

# %%
pollution_data_final = new_pollution_data.rename(index = {'description':'date'}, columns = {
    'United States : all fuels (utility-scale)' : 'all_fuels',
    'United States : coal' : 'coal',
    'United States : petroleum liquids' : 'petroleum_liquid',
    'United States : petroleum coke' : 'petroleum_coke',
    'United States : natural gas' : 'natural_gas',
    'United States : other gases' : 'other_gases',
    'United States : nuclear' : 'nuclear',
    'United States : conventional hydroelectric' : 'conventional_hydroelectric',
    'United States : wind' : 'wind',
    'United States : all utility-scale solar' : 'all_solar_utility-scale',
    'United States : geothermal' : 'geothermal',
    'United States : biomass' : 'biomass',
    'United States : wood and wood-derived fuels' : 'wood_fuels',
    'United States : other biomass' : 'other_biomass',
    'United States : hydro-electric pumped storage' : 'hydro-electric_pump_storage',
    'United States : other' : 'other',
    'United States : all solar' : 'all_solar',
    'United States : small-scale solar photovoltaic' : 'small-scale_solar_photovoltaic',
    'United States : all utility-scale solar' : 'all_solar_delete_this_one'  
})

# %%
pollution_data_final = pollution_data_final.index.name['date']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-8d1374d6654f> in <module>
# ----> 1 pollution_data_final = pollution_data_final.index.name(['date'])
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'name'

# %%
pollution_data_final.index.rename({'description':'date'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-5e69a3fc46c2> in <module>
# ----> 1 pollution_data_final.index.rename({'description':'date'})
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'rename'
